# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/data/data3_project.csv')
#查看前5筆檔案欄位資訊
df.head()
# Out:
#       InvoiceNo StockCode  ... member_start_date  first_trans_date
# 0  PS5327001158      JA01  ...        2019-12-09        2018-06-24
# 1  PS5335020955      KG06  ...        2018-10-21        2018-10-21
# 2  PS5335020955     BJ102  ...        2018-10-21        2018-10-21
# 3  PS5335020955    JZA3G1  ...        2018-10-21        2018-10-21
# 4  PS5444006919     BJ103  ...        2018-12-04        2018-12-04
#
# [5 rows x 10 columns]

# %%
#查看欄位
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'member_start_date',
#        'first_trans_date'],
#       dtype='object')

# %% [markdown]
# # **第一題**

# %%
mask = (df['InvoiceDate'] >= "2020-11-01") & (df['InvoiceDate'] <= "2020-11-30") 
df[mask]
# Out:
#             InvoiceNo StockCode  ... member_start_date  first_trans_date
# 1284117  PS5339008938     J0131  ...        2012-08-22        2012-07-06
# 1284118  PS5324024402   HB90A05  ...        2004-07-19        2012-12-09
# 1284119  PS5324024402     J0131  ...        2004-07-19        2012-12-09
# 1284120  PS5213023623     WD097  ...               NaN        2013-05-12
# 1284121  PS5336026954     J0132  ...        2019-07-10        2019-03-25
# ...               ...       ...  ...               ...               ...
# 1344561  PS5541009724      KQ02  ...        2014-12-25        2014-12-25
# 1344562  PS5541009724     BJ102  ...        2014-12-25        2014-12-25
# 1344563  PS5336027331    MAFAG4  ...        2003-09-02        2012-09-23
# 1344564  PS5336027331      KQ05  ...        2003-09-02        2012-09-23
# 1344565  PS5336027331     KX092  ...        2003-09-02        2012-09-23
#
# [60449 rows x 10 columns]

# %% [markdown]
# # **第二題**

# %%
mask = (df['UnitPrice']>=0) & (df['UnitPrice']<=3000)
df[mask]
# Out:
#             InvoiceNo StockCode  ... member_start_date  first_trans_date
# 0        PS5327001158      JA01  ...        2019-12-09        2018-06-24
# 1        PS5335020955      KG06  ...        2018-10-21        2018-10-21
# 2        PS5335020955     BJ102  ...        2018-10-21        2018-10-21
# 4        PS5444006919     BJ103  ...        2018-12-04        2018-12-04
# 5        PS5444006920     K8018  ...        2017-12-19        2017-12-19
# ...               ...       ...  ...               ...               ...
# 1404430  PS5324024941      KQ02  ...        2010-03-15        2012-07-11
# 1404431  PS5219002027    GAXFG1  ...        2020-12-08        2020-11-26
# 1404432  PS5219002027    MAB2G1  ...        2020-12-08        2020-11-26
# 1404433  PS5219002027     WD096  ...        2020-12-08        2020-11-26
# 1404434  PS5219002028    GAXFG2  ...        2020-12-23        2020-12-10
#
# [1123188 rows x 10 columns]

# %% [markdown]
# # **第三題**

# %%
cols = ['CustomerID', 'StockCode', 'Description']
df_csd = df[cols]
#查看前五筆資料
df_csd.head()
# Out:
#      CustomerID StockCode      Description
# 0  9.100002e+12      JA01      晶淬雪潔顏乳100ml
# 1  9.100003e+12      KG06    多肽亮眼乳霜20g-保濕型
# 2  9.100003e+12     BJ102     檸檬精油10ml MUI
# 3  9.100003e+12    JZA3G1   柚見快樂精油15ml MUI
# 4  9.100003e+12     BJ103  細花冬青香氛油10ml MUI

# %% [markdown]
# ![image.png](data:image/png;base64,...)
